# %% [markdown]
# # Reduce PDS data
#
# To _reduce_ PDS may be different across different datasets/product-types
#
# Here, we are going to work with MEX/HRSC data.

# %%
dataset = 'hrsc'

# %%
from gpt.helpers import collection

from importlib import reload
reload(collection)
# Out:
# <module 'gpt.helpers.collection' from '/mnt/data/repos/GMAP/gpt/gpt/helpers/collection.py'>

# %%
ls ../01_search-download_from_ode-pds/
# Out:
# 01_search_data_products.ipynb    download_ctx.geojson     search_ctx.geojson
# 02_download_data_products.ipynb  download_hirise.geojson  search_hirise.geojson
# data@                            download_hrsc.geojson    search_hrsc.geojson

# %%
from pathlib import Path

db_path = Path(f'../01_search-download_from_ode-pds/download_{dataset}.geojson')

archive = collection.from_geojson(db_path.as_posix())

# %%
archive
# Out:
#                                             geometry BB_georeferenced  \
# 0  MULTIPOLYGON (((-0.21680 3.84280, -0.21600 3.9...             True
# 1  MULTIPOLYGON (((-0.21680 3.84280, -0.21600 3.9...             True
# 2  POLYGON ((-1.73400 -11.89400, -1.73800 -11.644...             True
# 3  POLYGON ((-1.73400 -11.89400, -1.73800 -11.644...             True
#
#   Center_georeferenced Center_latitude Center_longitude  \
# 0                 True         -1.7901           0.2893
# 1                 True         -1.7901           0.2893
# 2                 True         -4.8102         358.8204
# 3                 True         -4.8102         358.8204
#
#                             Data_Set_Id Easternmost_longitude  \
# 0  MEX-M-HRSC-5-REFDR-MAPPROJECTED-V3.0               359.784
# 1  MEX-M-HRSC-5-REFDR-MAPPROJECTED-V3.0               359.784
# 2  MEX-M-HRSC-5-REFDR-MAPPROJECTED-V3.0               359.921
# 3  MEX-M-HRSC-5-REFDR-MAPPROJECTED-V3.0               359.921
#
#                                         External_url  \
# 0  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 1  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 2  https://ode.rsl.wustl.edu/mars/indexproductpag...
# 3  https://ode.rsl.wustl.edu/mars/indexproductpag...
#
#                                             FilesURL ihid  ...  \
# 0  https://ode.rsl.wustl.edu/mars/productfiles.as...  MEX  ...
# 1  https://ode.rsl.wustl.edu/mars/productfiles.as...  MEX  ...
# 2  https://ode.rsl.wustl.edu/mars/productfiles.as...  MEX  ...
# 3  https://ode.rsl.wustl.edu/mars/productfiles.as...  MEX  ...
#
#             UTC_start_time            UTC_stop_time Westernmost_longitude  \
# 0  2005-08-05T04:56:51.655  2005-08-05T04:59:53.671                 0.844
# 1  2005-08-05T04:56:51.655  2005-08-05T04:59:53.671                 0.844
# 2  2012-03-24T00:45:41.813  2012-03-24T00:49:36.820               357.866
# 3  2012-03-24T00:45:41.813  2012-03-24T00:49:36.820               357.866
#
#              Creation_date         Description            FileName  KBytes  \
# 0  2016-04-25T13:16:13.845   PRODUCT DATA FILE  H1998_0000_ND3.JP2  160069
# 1  2016-04-25T13:16:13.662  PRODUCT LABEL FILE  H1998_0000_ND3.LBL      10
# 2  2017-01-03T10:26:40.344   PRODUCT DATA FILE  HA482_0000_ND3.JP2  227392
# 3  2017-01-03T10:26:39.668  PRODUCT LABEL FILE  HA482_0000_ND3.LBL      10
#
#       Type                                                URL  \
# 0  Product  https://pds-geosciences.wustl.edu/mex/mex-m-hr...
# 1  Product  https://pds-geosciences.wustl.edu/mex/mex-m-hr...
# 2  Product  https://pds-geosciences.wustl.edu/mex/mex-m-hr...
# 3  Product  https://pds-geosciences.wustl.edu/mex/mex-m-hr...
#
#                                    file_path
# 0  ./data/MEX/HRSC/REFDR3/h1998_0000_nd3.jp2
# 1  ./data/MEX/HRSC/REFDR3/h1998_0000_nd3.lbl
# 2  ./data/MEX/HRSC/REFDR3/ha482_0000_nd3.jp2
# 3  ./data/MEX/HRSC/REFDR3/ha482_0000_nd3.lbl
#
# [4 rows x 40 columns]

# %% [markdown]
# ## Data and metadata processing
#
# We have in our data store those four product files:
# ```
# 0  ./data/MEX/HRSC/REFDR3/h1998_0000_nd3.jp2
# 1  ./data/MEX/HRSC/REFDR3/h1998_0000_nd3.lbl
# 2  ./data/MEX/HRSC/REFDR3/ha482_0000_nd3.jp2
# 3  ./data/MEX/HRSC/REFDR3/ha482_0000_nd3.lbl
# ```
# corresponding to image/data and header/metadata files for two data products: `h1998_0000_nd3` and `ha482_0000_nd3`.
#
# Images are in [JPEG2000]() format, while the headers are in [PDS LABEL]() format.
#
# We want to convert those JP2 images into geotiff and just check what PDS LABEL files look like.

# %% [markdown]
# ### JP2 to GeoTIFF with `gdal_translate`
#
# In the [GDAL toolkit](https://gdal.org/programs/raster_common_options.html), `gdal_translate` can be used to do this format transformation.
#
# The simplest for of the command is:
# ```bash
# $ gdal_translate input.jp2 result.tif
# ```
# , `gdal_translate` should be able to understand the file formats we are refeering to (JP2, GeoTIFF, respectively) and do the conversion automatically.
#
# We can, though, add [some options](https://gdal.org/programs/gdal_translate.html) to optimize (size, performance) the generated GeoTIFF raster.
# For isntance, we could add options `COMPRESS=JPEG` and `TILED=YES` for a smaller image and tiled for optimized partial reading [COG]():
# ```bash
# $ gdal_translate -of GTiff -co COMPRESS=JPEG -co TILED=YES input.jp2 result.tif
# ```

# %% [markdown]
# For educational reasons, I will run `gdal_translate` from here, inside the Python environment, with the help of the [sh](https://amoffat.github.io/sh/index.html), a binder for command line commands to Python.

# %%
from sh import gdal_translate

gdal_translate = gdal_translate.bake(of='GTiff', co='COMPRESS=JPEG', _long_prefix="-", _long_sep=" ")

# %%
import os

path_out = './data/MEX/HRSC/Reduced'
files_out = []

os.makedirs(path_out, exist_ok=True)

# %%
pid = 'h1998_0000_nd3'

output = f'{path_out}/{pid}.tif'

gdal_translate(f'./data/MEX/HRSC/REFDR3/{pid}.jp2', output)

files_out.append(output)

# %%
pid = 'ha482_0000_nd3'

output = f'{path_out}/{pid}.tif'

gdal_translate(f'./data/MEX/HRSC/REFDR3/{pid}.jp2', output)

files_out.append(output)

# %%
# %matplotlib inline

def plot(files):
    import rasterio
    from matplotlib import pyplot as plt
    from rasterio.plot import show
    
    n_files = len(files)
    fig, axs = plt.subplots(1, n_files, figsize=(24,12))
    if n_files == 1:
        axs = [axs]
    for i, fname in enumerate(files):
        title = fname.split('/')[-1].split('.')[:-1]
        img = rasterio.open(fname)
        show((img, 1), ax=axs[i], cmap='pink', title=title)

# %%
plot(files_out)

# %%
# %cat ./data/MEX/HRSC/REFDR3/h1998_0000_nd3.lbl
# Out:
# PDS_VERSION_ID                    = PDS3
#
# /* FILE DATA ELEMENTS */
#
# RECORD_TYPE                       = STREAM
#
# /* POINTERS TO DATA OBJECTS */
#
# ^COMPRESSED_FILE                  = "H1998_0000_ND3.JP2"
#
# /* IDENTIFICATION DATA ELEMENTS */
#
# DATA_SET_ID                       = "MEX-M-HRSC-5-REFDR-MAPPROJECTED-V3.0"
# DATA_SET_NAME                     = "MARS EXPRESS HRSC MAP PROJECTED REFDR
#                                      V3.0"
# DETECTOR_ID                       = MEX_HRSC_NADIR
# EVENT_TYPE                        = "MARS-LOCAL-CARTOGRAPHY-Lc-La-Tc"
# INSTRUMENT_HOST_ID                = MEX
# INSTRUMENT_HOST_NAME              = "MARS EXPRESS"
# INSTRUMENT_ID                     = HRSC
# INSTRUMENT_NAME                   = "HIGH RESOLUTION STEREO CAMERA"
# MISSION_NAME                      = "MARS EXPRESS"
# MISSION_PHASE_NAME                = MR_Phase_7
# PROCESSING_LEVEL_ID               = 3
# PRODUCT_CREATION_TIME             = 2016-03-09T16:25:58.000Z
# PRODUCT_ID                        = "H1998_0000_ND3.JP2"
# RELEASE_ID                        = 0025
# REVISION_ID                       = 0000
#
# /* QUALITY DATA ELEMENTS */
#
# DATA_QUALITY_ID                   = 1
# DATA_QUALITY_DESC                 = "Data calculated based on original
#                                      SPICE kernels"
#
# /* TIME DATA ELEMENTS */
#
# SPACECRAFT_CLOCK_START_COUNT      = "1/0071297771.56203"
# SPACECRAFT_CLOCK_STOP_COUNT       = "1/0071298014.46897"
# START_TIME                        = 2005-08-05T04:56:51.655Z
# STOP_TIME                         = 2005-08-05T04:59:53.671Z
#
# /* ORBITAL DATA ELEMENTS */
#
# ASCENDING_NODE_LONGITUDE          = 186.39
# MAXIMUM_RESOLUTION                = 11.1 <m/pixel>
# FOOTPRINT_POINT_LATITUDE          = (-7.73791,-7.73934,-7.74105,-7.74241,
#                                      -7.36006,-7.10487,-6.84939,-6.59373,
#                                      -6.34009,-6.09226,-5.84427,-5.59608,
#                                      -5.34766,-5.09915,-4.85044,-4.47757,
#                                      -4.23673,-3.99572,-3.75459,-3.51329,
#                                      -3.27186,-3.0303,-2.78858,-2.54673,
#                                      -2.30476,-2.06671,-1.83283,-1.59885,
#                                      -1.36474,-1.13052,-0.896199,-0.661758,
#                                      -0.427222,-0.192595,0.0420955,0.276919,
#                                      0.511816,0.746812,0.981873,1.43548,
#                                      1.88935,2.11636,2.34345,2.57061,2.79783
#                                      ,3.02508,3.2524,3.47977,3.70721,3.93462
#                                      ,4.16194,4.16265,4.16311,4.16328,
#                                      3.93587,3.70854,3.48116,3.25388,3.02664
#                                      ,2.79945,2.57236,2.34527,1.89131,
#                                      1.43759,0.98415,0.749153,0.51424,
#                                      0.279415,0.044663,-0.189979,-0.424525,
#                                      -0.658975,-0.893329,-1.12758,-1.36173,
#                                      -1.59576,-1.82971,-2.06352,-2.30152,
#                                      -2.54343,-2.78521,-3.02687,-3.26839,
#                                      -3.50975,-3.751,-3.99207,-4.23302,
#                                      -4.4738,-4.7222,-4.97095,-5.21954,
#                                      -5.46795,-5.71618,-5.96406,-6.3359,
#                                      -6.71737,-6.97289,-7.22818,-7.48318,
#                                      -7.73791)
# FOOTPRINT_POINT_LONGITUDE         = (360.956,360.686,360.298,359.915,
#                                      359.735,359.737,359.739,359.741,359.743
#                                      ,359.745,359.747,359.749,359.75,359.752
#                                      ,359.754,359.756,359.758,359.759,359.76
#                                      ,359.762,359.763,359.764,359.765,
#                                      359.767,359.768,359.769,359.77,359.771,
#                                      359.772,359.773,359.774,359.774,359.775
#                                      ,359.776,359.777,359.777,359.778,
#                                      359.779,359.779,359.78,359.781,359.782,
#                                      359.782,359.783,359.783,359.783,359.783
#                                      ,359.784,359.784,359.784,359.877,360.23
#                                      ,360.524,360.849,360.85,360.852,360.851
#                                      ,360.852,360.852,360.853,360.855,
#                                      360.856,360.858,360.861,360.863,360.865
#                                      ,360.866,360.868,360.869,360.871,
#                                      360.873,360.875,360.877,360.88,360.882,
#                                      360.884,360.886,360.888,360.891,360.893
#                                      ,360.896,360.898,360.901,360.904,
#                                      360.906,360.909,360.911,360.914,360.918
#                                      ,360.921,360.924,360.927,360.93,360.939
#                                      ,360.94,360.945,360.949,360.953,360.96,
#                                      360.956)
# ORBIT_NUMBER                      = 1998
# ORBITAL_ECCENTRICITY              = 0.572
# ORBITAL_INCLINATION               = 86.59
# ORBITAL_SEMIMAJOR_AXIS            = 8622.84
# PERIAPSIS_ALTITUDE                = 296.73
# PERIAPSIS_ARGUMENT_ANGLE          = 7.41
# PERIAPSIS_TIME                    = 2005-08-05T05:00:43.000Z
# SPACECRAFT_ORIENTATION            = (0.0,1.0,0.0)
# ^MEX_ORIENTATION_DESC             = "MEX_ORIENTATION_DESC.TXT"
# SPACECRAFT_POINTING_MODE          = ACROSSTRACK
# ^MEX_POINTING_DESC                = "MEX_POINTING_DESC.TXT"
# RIGHT_ASCENSION                   = -1e+32
# DECLINATION                       = -1e+32
# OFFSET_ANGLE                      = -0.5
# SPACECRAFT_SOLAR_DISTANCE         = 2.07011e+08
# TARGET_NAME                       = MARS
#
# /* CAMERA DATA ELEMENTS */
#
# DETECTOR_TEMPERATURE              = 18.3705 <degC>
# FOCAL_PLANE_TEMPERATURE           = 9.195 <degC>
# INST_CMPRS_NAME                   = "DISCRETE COSINE TRANSFORMATION (DCT)"
# INST_CMPRS_RATIO                  = 7.09913
# INST_CMPRS_QUALITY                = 0
# INST_CMPRS_QUANTZ_TBL_ID          = 0
# INSTRUMENT_TEMPERATURE            = 11.8457 <degC>
# LENS_TEMPERATURE                  = 10.2145 <degC>
# MACROPIXEL_SIZE                   = 1
# MISSING_FRAMES                    = 0
# PIXEL_SUBSAMPLING_FLAG            = N
# SIGNAL_CHAIN_ID                   = 0
#
# /* RADIOMETRIC DATA ELEMENTS */
#
# BANDWIDTH                         = 177.0 <nm>
# CENTER_FILTER_WAVELENGTH          = 677.5 <nm>
# RADIANCE_OFFSET                   = 3.7714 <W*m**-2*sr**-1>
# RADIANCE_SCALING_FACTOR           = 0.0113768 <W*m**-2*sr**-1>
# REFLECTANCE_SCALING_FACTOR        = 0.000258993
# MEX:REFLECTANCE_OFFSET            = 0.0858562
#
# /* IMAGE OBJECT DEFINITIONS */
#
# OBJECT                            = IMAGE
#   INTERCHANGE_FORMAT              = BINARY
#   LINES                           = 56456
#   LINE_SAMPLES                    = 6105
#   SAMPLE_TYPE                     = UNSIGNED_INTEGER
#   SAMPLE_BITS                     = 8
#   BANDS                           = 1
#   BAND_STORAGE_TYPE               = BAND_SEQUENTIAL
#   MAXIMUM                         = 150
#   MEAN                            = 99.5044
#   MINIMUM                         = 74
#   STANDARD_DEVIATION              = 6.74372
# END_OBJECT                        = IMAGE
#
# /* MAP OBJECT DEFINITIONS */
#
# OBJECT                            = IMAGE_MAP_PROJECTION
#   ^DATA_SET_MAP_PROJECTION_CATALOG= "DSMAP.CAT"
#   A_AXIS_RADIUS                   = 3396.0 <km>
#   B_AXIS_RADIUS                   = 3396.0 <km>
#   C_AXIS_RADIUS                   = 3396.0 <km>
#   CENTER_LATITUDE                 = 0.0
#   CENTER_LONGITUDE                = 0.0
#   COORDINATE_SYSTEM_NAME          = PLANETOGRAPHIC
#   COORDINATE_SYSTEM_TYPE          = "BODY-FIXED ROTATING"
#   EASTERNMOST_LONGITUDE           = 0.96
#   FIRST_STANDARD_PARALLEL         = "N/A"
#   LINE_FIRST_PIXEL                = 1
#   LINE_LAST_PIXEL                 = 56456
#   LINE_PROJECTION_OFFSET          = 19740.0
#   MAP_PROJECTION_ROTATION         = 0.0
#   MAP_PROJECTION_TYPE             = SINUSOIDAL
#   MAP_RESOLUTION                  = 4741.71043093333 <pixel/degree>
#   MAP_SCALE                       = 0.0125 <km/pixel>
#   MAXIMUM_LATITUDE                = 4.16328
#   MINIMUM_LATITUDE                = -7.74241
#   POSITIVE_LONGITUDE_DIRECTION    = EAST
#   REFERENCE_LATITUDE              = "N/A"
#   REFERENCE_LONGITUDE             = "N/A"
#   SAMPLE_FIRST_PIXEL              = 1
#   SAMPLE_LAST_PIXEL               = 6105
#   SAMPLE_PROJECTION_OFFSET        = 1283.0
#   SECOND_STANDARD_PARALLEL        = "N/A"
#   WESTERNMOST_LONGITUDE           = -0.265
# END_OBJECT                        = IMAGE_MAP_PROJECTION
#
#
# /* The JPEG2000 image data file associated with this label. */
#
# OBJECT                    = COMPRESSED_FILE
#   FILE_NAME               = "H1998_0000_ND3.JP2"
#   RECORD_TYPE             = UNDEFINED
#   FILE_RECORDS            = UNK
#   ENCODING_TYPE           = "JP2"
#   INTERCHANGE_FORMAT      = BINARY
#   UNCOMPRESSED_FILE_NAME  = "H1998_0000_ND3.IMG"
#   REQUIRED_STORAGE_BYTES  = "344694405"
#   ^DESCRIPTION            = "JP2INFO.TXT"
# END_OBJECT                = COMPRESSED_FILE
#
# END

# %%
# %cat ./data/MEX/HRSC/REFDR3/ha482_0000_nd3.lbl
# Out:
# PDS_VERSION_ID                    = PDS3
#
# /* FILE DATA ELEMENTS */
#
# RECORD_TYPE                       = STREAM
#
# /* POINTERS TO DATA OBJECTS */
#
# ^COMPRESSED_FILE                  = "HA482_0000_ND3.JP2"
#
# /* IDENTIFICATION DATA ELEMENTS */
#
# DATA_SET_ID                       = "MEX-M-HRSC-5-REFDR-MAPPROJECTED-V3.0"
# DATA_SET_NAME                     = "MARS EXPRESS HRSC MAP PROJECTED REFDR
#                                      V3.0"
# DETECTOR_ID                       = MEX_HRSC_NADIR
# EVENT_TYPE                        = "MARS-REGIONAL-MAPPING-Im-Fl-La"
# INSTRUMENT_HOST_ID                = MEX
# INSTRUMENT_HOST_NAME              = "MARS EXPRESS"
# INSTRUMENT_ID                     = HRSC
# INSTRUMENT_NAME                   = "HIGH RESOLUTION STEREO CAMERA"
# MISSION_NAME                      = "MARS EXPRESS"
# MISSION_PHASE_NAME                = ME_Phase_25
# PROCESSING_LEVEL_ID               = 3
# PRODUCT_CREATION_TIME             = 2016-10-27T12:16:28.000Z
# PRODUCT_ID                        = "HA482_0000_ND3.JP2"
# RELEASE_ID                        = 0107
# REVISION_ID                       = 0000
#
# /* QUALITY DATA ELEMENTS */
#
# DATA_QUALITY_ID                   = 1
# DATA_QUALITY_DESC                 = "Data calculated based on original
#                                      SPICE kernels"
#
# /* TIME DATA ELEMENTS */
#
# SPACECRAFT_CLOCK_START_COUNT      = "1/0280629901.07282"
# SPACECRAFT_CLOCK_STOP_COUNT       = "1/0280630240.27629"
# START_TIME                        = 2012-03-24T00:45:41.813Z
# STOP_TIME                         = 2012-03-24T00:49:36.820Z
#
# /* ORBITAL DATA ELEMENTS */
#
# ASCENDING_NODE_LONGITUDE          = 17.22
# MAXIMUM_RESOLUTION                = 16.5 <m/pixel>
# FOOTPRINT_POINT_LATITUDE          = (-11.8935,-11.8942,-11.8935,-11.3985,
#                                      -11.0186,-10.7654,-10.5124,-10.2598,
#                                      -10.0021,-9.7435,-9.48542,-9.2276,
#                                      -8.96638,-8.70279,-8.43954,-8.17664,
#                                      -7.90999,-7.64141,-7.37322,-7.1054,
#                                      -6.83181,-6.42188,-6.14912,-5.87048,
#                                      -5.59222,-5.31442,-5.03217,-4.74898,
#                                      -4.46627,-4.17927,-3.89128,-3.60379,
#                                      -3.31094,-2.87215,-2.42719,-2.12999,
#                                      -1.67827,-1.37637,-0.91726,-0.610783,
#                                      -0.299773,0.011498,0.483913,0.799524,
#                                      1.12019,1.44038,1.76537,2.09005,2.27846
#                                      ,2.28371,2.29108,2.29513,2.29997,
#                                      2.13937,1.81388,1.48778,1.16679,
#                                      0.845076,0.528688,0.0548388,-0.257108,
#                                      -0.569154,-0.876369,-1.33684,-1.63939,
#                                      -2.09242,-2.39027,-2.83651,-3.12955,
#                                      -3.42308,-3.85812,-4.14669,-4.43466,
#                                      -4.71793,-5.00156,-5.2847,-5.56317,
#                                      -5.84197,-6.25808,-6.53159,-6.80549,
#                                      -7.21407,-7.4825,-7.75149,-8.15357,
#                                      -8.41695,-8.68057,-8.94478,-9.20678,
#                                      -9.46509,-9.7237,-9.98263,-10.2412,
#                                      -10.4942,-10.7476,-11.0013,-11.2552,
#                                      -11.63,-11.8781,-11.8935)
# FOOTPRINT_POINT_LONGITUDE         = (359.359,358.881,358.26,358.254,358.248
#                                      ,358.243,358.239,358.234,358.23,358.221
#                                      ,358.22,358.216,358.211,358.206,358.201
#                                      ,358.196,358.19,358.184,358.178,358.172
#                                      ,358.165,358.155,358.148,358.14,358.132
#                                      ,358.124,358.117,358.108,358.099,
#                                      358.092,358.083,358.074,358.066,358.052
#                                      ,358.038,358.028,358.012,358.002,
#                                      357.986,357.974,357.962,357.95,357.932,
#                                      357.92,357.907,357.893,357.88,357.866,
#                                      358.193,358.524,358.991,359.253,359.572
#                                      ,359.916,359.912,359.909,359.906,
#                                      359.903,359.9,359.896,359.893,359.89,
#                                      359.887,359.883,359.88,359.876,359.874,
#                                      359.87,359.868,359.865,359.861,359.858,
#                                      359.856,359.854,359.85,359.848,359.847,
#                                      359.844,359.841,359.839,359.836,359.833
#                                      ,359.83,359.829,359.825,359.823,359.819
#                                      ,359.818,359.816,359.814,359.811,
#                                      359.809,359.807,359.804,359.802,359.8,
#                                      359.798,359.794,359.792,359.359)
# ORBIT_NUMBER                      = 10482
# ORBITAL_ECCENTRICITY              = 0.578
# ORBITAL_INCLINATION               = 86.87
# ORBITAL_SEMIMAJOR_AXIS            = 8832.26
# PERIAPSIS_ALTITUDE                = 334.6
# PERIAPSIS_ARGUMENT_ANGLE          = 328.58
# PERIAPSIS_TIME                    = 2012-03-24T00:40:40.000Z
# SPACECRAFT_ORIENTATION            = (0.0,1.0,0.0)
# ^MEX_ORIENTATION_DESC             = "MEX_ORIENTATION_DESC.TXT"
# SPACECRAFT_POINTING_MODE          = ACROSSTRACK
# ^MEX_POINTING_DESC                = "MEX_POINTING_DESC.TXT"
# RIGHT_ASCENSION                   = -1e+32
# DECLINATION                       = -1e+32
# OFFSET_ANGLE                      = 1.3
# SPACECRAFT_SOLAR_DISTANCE         = 2.48204e+08
# TARGET_NAME                       = MARS
#
# /* CAMERA DATA ELEMENTS */
#
# DETECTOR_TEMPERATURE              = 18.5744 <degC>
# FOCAL_PLANE_TEMPERATURE           = 8.7872 <degC>
# INST_CMPRS_NAME                   = "DISCRETE COSINE TRANSFORMATION (DCT)"
# INST_CMPRS_RATIO                  = 6.35353
# INST_CMPRS_QUALITY                = 0
# INST_CMPRS_QUANTZ_TBL_ID          = 0
# INSTRUMENT_TEMPERATURE            = 12.0496 <degC>
# LENS_TEMPERATURE                  = 9.195 <degC>
# MACROPIXEL_SIZE                   = 1
# MISSING_FRAMES                    = 0
# PIXEL_SUBSAMPLING_FLAG            = N
# SIGNAL_CHAIN_ID                   = 0
#
# /* RADIOMETRIC DATA ELEMENTS */
#
# BANDWIDTH                         = 177.0 <nm>
# CENTER_FILTER_WAVELENGTH          = 677.5 <nm>
# RADIANCE_OFFSET                   = 1.02201 <W*m**-2*sr**-1>
# RADIANCE_SCALING_FACTOR           = 0.0129588 <W*m**-2*sr**-1>
# REFLECTANCE_SCALING_FACTOR        = 0.000424099
# MEX:REFLECTANCE_OFFSET            = 0.033447
#
# /* IMAGE OBJECT DEFINITIONS */
#
# OBJECT                            = IMAGE
#   INTERCHANGE_FORMAT              = BINARY
#   LINES                           = 67328
#   LINE_SAMPLES                    = 10150
#   SAMPLE_TYPE                     = UNSIGNED_INTEGER
#   SAMPLE_BITS                     = 8
#   BANDS                           = 1
#   BAND_STORAGE_TYPE               = BAND_SEQUENTIAL
#   MAXIMUM                         = 255
#   MEAN                            = 87.0873
#   MINIMUM                         = 1
#   STANDARD_DEVIATION              = 30.276
# END_OBJECT                        = IMAGE
#
# /* MAP OBJECT DEFINITIONS */
#
# OBJECT                            = IMAGE_MAP_PROJECTION
#   ^DATA_SET_MAP_PROJECTION_CATALOG= "DSMAP.CAT"
#   A_AXIS_RADIUS                   = 3396.0 <km>
#   B_AXIS_RADIUS                   = 3396.0 <km>
#   C_AXIS_RADIUS                   = 3396.0 <km>
#   CENTER_LATITUDE                 = 0.0
#   CENTER_LONGITUDE                = 359.0
#   COORDINATE_SYSTEM_NAME          = PLANETOGRAPHIC
#   COORDINATE_SYSTEM_TYPE          = "BODY-FIXED ROTATING"
#   EASTERNMOST_LONGITUDE           = 359.916
#   FIRST_STANDARD_PARALLEL         = "N/A"
#   LINE_FIRST_PIXEL                = 1
#   LINE_LAST_PIXEL                 = 67328
#   LINE_PROJECTION_OFFSET          = 10927.0
#   MAP_PROJECTION_ROTATION         = 0.0
#   MAP_PROJECTION_TYPE             = SINUSOIDAL
#   MAP_RESOLUTION                  = 4741.71043093333 <pixel/degree>
#   MAP_SCALE                       = 0.0125 <km/pixel>
#   MAXIMUM_LATITUDE                = 2.29997
#   MINIMUM_LATITUDE                = -11.8942
#   POSITIVE_LONGITUDE_DIRECTION    = EAST
#   REFERENCE_LATITUDE              = "N/A"
#   REFERENCE_LONGITUDE             = "N/A"
#   SAMPLE_FIRST_PIXEL              = 1
#   SAMPLE_LAST_PIXEL               = 10150
#   SAMPLE_PROJECTION_OFFSET        = 5797.0
#   SECOND_STANDARD_PARALLEL        = "N/A"
#   WESTERNMOST_LONGITUDE           = 357.866
# END_OBJECT                        = IMAGE_MAP_PROJECTION
#
#
# /* The JPEG2000 image data file associated with this label. */
#
# OBJECT                    = COMPRESSED_FILE
#   FILE_NAME               = "HA482_0000_ND3.JP2"
#   RECORD_TYPE             = UNDEFINED
#   FILE_RECORDS            = UNK
#   ENCODING_TYPE           = "JP2"
#   INTERCHANGE_FORMAT      = BINARY
#   UNCOMPRESSED_FILE_NAME  = "HA482_0000_ND3.IMG"
#   REQUIRED_STORAGE_BYTES  = "683409650"
#   ^DESCRIPTION            = "JP2INFO.TXT"
# END_OBJECT                = COMPRESSED_FILE
#
# END
